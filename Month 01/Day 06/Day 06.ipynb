# %% [markdown]
# ![image.png](attachment:d010ad12-12c2-4a00-8338-5f51760509c1.png)

# %% [markdown]
# ![image.png](attachment:201662c3-ff9f-4eb5-8fd9-aa2221084f13.png)

# %%
def calculate_area(radius:float) -> float:
    if radius<0:
        return 0
    return 3.14 * (radius**2)
print(calculate_area(5))
# Out:
# 78.5

# %% [markdown]
# ![image.png](attachment:80783585-e3ab-4ab8-8691-9a0009a32d71.png)

# %%
x=10
def change_x(x):
    print(x)
    
change_x(20)
# Out:
# 20

# %% [markdown]
# ![image.png](attachment:ff5df3d2-e1ea-478f-b544-4de913d03eea.png)

# %%
def add(a, b):
    a+b
res = add(5, 5)
print(res)
# Out:
# None

# %% [markdown]
# ![image.png](attachment:910268a1-7196-432b-9d10-4cf2ebfb93c9.png)

# %%
def connect(port=3306):
    print(f"Connecting to {port}")
connect()
connect(5432)
# Out:
# Connecting to 3306
# Connecting to 5432

# %% [markdown]
# ![image.png](attachment:ae1a3154-0043-4d47-bdcc-ade03c954350.png)

# %%
def is_even(num):
    if num%2==0:
        return True
    else:
        return False
is_even(10)
# Out:
# True

# %%
is_even(11)
# Out:
# False
