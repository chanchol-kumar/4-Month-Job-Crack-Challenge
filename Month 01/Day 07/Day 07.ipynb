# %% [markdown]
# ![image.png](attachment:f8149d2d-a505-4038-84e2-453198b65d2c.png)

# %%
while True:
    try:
        val = int(input("Enter Number: "))
        print(100/val)
        break
    except ValueError:
        print("Text is not allowed. ")
    except ZeroDivisionError:
        print("Cannot Divide by zero.")
# Out:
# Enter Number:  df
# Text is not allowed.
# Enter Number:  0
# Cannot Divide by zero.
# Enter Number:  5
# 20.0

# %% [markdown]
# ![image.png](attachment:b30054f8-dc32-4aa3-981b-ca1ee290379f.png)

# %%
while True:
    try:
        age = int(input("Enter Your Age: "))
        print(f"Your age is {age}")
        break
    except ValueError:
        print("Number Only")
# Out:
# Enter Your Age:  twenty
# Number Only
# Enter Your Age:  20
# Your age is 20

# %% [markdown]
# ![image.png](attachment:de7b2234-5067-47c6-9a69-df0e7e8089ab.png)

# %%
while True:
    try:
        x = int(input("Enter Number: "))
        print(100/x)
        break
    except ValueError:
        print("Text is not allowed. ")
    except ZeroDivisionError:
        print("Cannot Divide by zero.")
# Out:
# Enter Number:  df
# Text is not allowed.
# Enter Number:  0
# Cannot Divide by zero.
# Enter Number:  10
# 10.0

# %% [markdown]
# ![image.png](attachment:78729088-0971-44bf-86cd-1dde690a6977.png)

# %%
while True:
    try:
        a = int(input("Enter Number: "))
        b = int(input("Enter Number: "))
        print(a/b)
        print("Execution Complete")
        break
    except ValueError:
        print("Text is not allowed. ")
    except ZeroDivisionError:
        print("Cannot Divide by zero.")
# Out:
# Enter Number:  5
# Enter Number:  0
# Cannot Divide by zero.
# Execution Complete
# Enter Number:  5
# Enter Number:  5
# 1.0
# Execution Complete

# %% [markdown]
# ![image.png](attachment:46f9a944-b710-4d18-9aaa-e2890d9356c8.png)

# %%
while True:
    try:
        n = int(input("Enter a number: "))
        if n < 0:
            raise ValueError("No negatives")
        print(n)
        break
    except ValueError:
        print("Text is not allowed. ")
