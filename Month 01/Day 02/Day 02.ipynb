# %% [markdown]
# ![image.png](attachment:cef2689c-357e-4b58-abc4-bc003c1c3ae9.png)

# %%
score = 33

if score >= 90:
    grade = "A"
elif score >= 80:
    grade = "B"
else:
    grade = "C"

status = "Fail" if score <= 33 else grade

print(f"You result is {status}")
# Out:
# You result is Fail

# %% [markdown]
# ![image.png](attachment:75ce5ddf-bd7a-4c50-830f-d3e777b4b440.png)

# %%
user = None

status = "admin, You can Access" if user != None else "sorry,You can't access!"
print(status)
# Out:
# sorry,You can't access!

# %% [markdown]
# ![image.png](attachment:ea9c755b-8c8a-476a-90a4-16c96df85e42.png)

# %%
print(0.1 + 0.2)
print(0.1 + 0.2 == 0.3)
print(round(0.1 + 0.2, 2) == 0.3)
# Out:
# 0.30000000000000004
# False
# True

# %% [markdown]
# ![image.png](attachment:3ca6b75c-3515-4c0a-94ad-51d2bd6bbb52.png)

# %%
data = []
if len(data) == 0:
    print("No data")
else:
    print("Data Found")
# Out:
# No data
