# %% [markdown]
# ![image.png](attachment:9ebc9834-13a2-46d4-87e2-479f5fec1121.png)

# %% [markdown]
# ![image.png](attachment:87f5d77a-249b-43fc-afd0-cc35789cd78d.png)

# %%
user = {
    "Id":1,
    "Name": "Admin",
    "Email": "chanchol.kumar20@gmail.com"
}
email = user.get("Email", "No Email Found")
print(email)
print()

for key, val in user.items():
    print(f"{key}: {val}")
# Out:
# chanchol.kumar20@gmail.com
#
# Id: 1
# Name: Admin
# Email: chanchol.kumar20@gmail.com

# %% [markdown]
# ![image.png](attachment:c87b527b-1ab7-4e84-9a89-753bb44546b4.png)

# %%
lst = []
st = set()
for i in range(1, 10000000):
    lst.append(i)
    st.add(i)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[35], line 2
#       1 # ফাকা সেট তৈরি
# ----> 2 s = set()
#       4 # 1 থেকে 10 পর্যন্ত সংখ্যা add করা
#       5 for i in range(1, 11):
#
# TypeError: 'tuple' object is not callable

# %% [markdown]
# ![image.png](attachment:b61c081c-39e6-4830-b72e-3cf35c28f816.png)

# %%
user = {"id": 1}
user.get("Email","Not Found")
# Out:
# 'Not Found'

# %% [markdown]
# ![image.png](attachment:14b3b079-44c4-4ecf-8ec7-b5b4675469a7.png)

# %%
data = "banana"
freq = {}
for item in data:
    if item in freq:
        freq[item] += 1
    else:
        freq[item] = 1
print(freq)
# Out:
# {'b': 2, 'a': 3, 'n': 2}

# %% [markdown]
# ![image.png](attachment:b2e551e8-c24d-41bd-b341-62061742a3e2.png)

# %%
defaults = {"theme": "Light", "audio": "on"}
user_pref = {"theme": "dark"}

user_pref.update(defaults)
user_pref
defaults
# Out:
# {'theme': 'Light', 'audio': 'on'}
